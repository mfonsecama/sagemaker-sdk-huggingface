# %% [markdown]
# # Huggingface Sagemaker-sdk extension example using `Trainer` class

# %% [markdown]
# ## Installs requirements if you haven´t already done it and sets up ipywidgets for datasets in sagemaker studio

# %%
# %%capture
# !pip install -r ../requirements.txt --upgrade

# %%
# %%capture
import os 
import IPython
if 'SAGEMAKER_TRAINING_MODULE' in os.environ:
    # !conda install -c conda-forge ipywidgets -y
    IPython.Application.instance().kernel.do_shutdown(True) # has to restart kernel so changes are used

# %% [markdown]
# ## Initializing Sagemaker Session with local AWS Profile

# %% [markdown]
# From outside these notebooks, `get_execution_role()` will return an exception because it does not know what is the role name that SageMaker requires.
#
# To solve this issue, pass the IAM role name instead of using `get_execution_role()`.
#
# Therefore you have to create an IAM-Role with correct permission for sagemaker to start training jobs and download files from s3. Beware that you need s3 permission on bucket-level `"arn:aws:s3:::sagemaker-*"` and on object-level     `"arn:aws:s3:::sagemaker-*/*"`.
#
# You can read [here](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-roles.html) how to create a role with right permissions.

# %%
# local aws profile configured in ~/.aws/credentials
local_profile_name='hf-sm' # optional if you only have default configured

# role name for sagemaker -> needs the described permissions from above
role_name = "SageMakerRole"

# %%
import sagemaker
import os
try:
    sess = sagemaker.Session()
    role = sagemaker.get_execution_role()
except Exception:
    import boto3
    # creates a boto3 session using the local profile we defined
    if local_profile_name:
        os.environ['AWS_PROFILE'] = local_profile_name # setting env var bc local-mode cannot use boto3 session
        #bt3 = boto3.session.Session(profile_name=local_profile_name)
        #iam = bt3.client('iam')
        # create sagemaker session with boto3 session
        #sess = sagemaker.Session(boto_session=bt3)
    iam = boto3.client('iam')
    sess = sagemaker.Session()
    # get role arn
    role = iam.get_role(RoleName=role_name)['Role']['Arn']
    


print(role)
# Out:
# Couldn't call 'get_role' to get Role ARN from role name philipp to get Role path.
# arn:aws:iam::558105141721:role/SageMakerRole

# %% [markdown]
# ### Sagemaker Session prints

# %%
print(sess.list_s3_files(sess.default_bucket(),'datasets/')) # list objects in s3 under datsets/
print(sess.default_bucket()) # s3 bucketname
print(sess.boto_region_name) # aws region of sagemaker session
# Out:
# ['datasets/imdb/small/test/dataset.arrow', 'datasets/imdb/small/test/dataset_info.json', 'datasets/imdb/small/test/state.json', 'datasets/imdb/small/test/test_dataset.pt', 'datasets/imdb/small/train/dataset.arrow', 'datasets/imdb/small/train/dataset_info.json', 'datasets/imdb/small/train/state.json', 'datasets/imdb/small/training/train_dataset.pt']
# sagemaker-eu-central-1-558105141721
# eu-central-1

# %% [markdown]
# # Imports
#
# Since we are using the `.py` module directly from `huggingface/` we have to adjust our `sys.path` to be able to import our estimator

# %%
import sys, os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# # Preprocessing the data

# %%
from datasets import load_dataset
from transformers import AutoTokenizer

# %%
# load dataset
dataset = load_dataset('imdb')

# download tokenizer
tokenizer = AutoTokenizer.from_pretrained('distilbert-base-uncased')

#helper tokenizer function
def tokenize(batch):
    return tokenizer(batch['text'], padding='max_length', truncation=True)

# load dataset
train_dataset, test_dataset = load_dataset('imdb', split=['train', 'test'])
test_dataset = test_dataset.shuffle().select(range(10000)) # smaller the size for test dataset to 10k 

# sample a to small dataset for training
#train_dataset = train_dataset.shuffle().select(range(2000)) # smaller the size for test dataset to 10k 
#test_dataset = test_dataset.shuffle().select(range(150)) # smaller the size for test dataset to 10k 


# tokenize dataset
train_dataset = train_dataset.map(tokenize, batched=True, batch_size=len(train_dataset))
test_dataset = test_dataset.map(tokenize, batched=True, batch_size=len(test_dataset))

# set format for pytorch
train_dataset.rename_column_("label", "labels")
train_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'labels'])
test_dataset.rename_column_("label", "labels")
test_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'labels'])
# Out:
# Reusing dataset imdb (/Users/philippschmid/.cache/huggingface/datasets/imdb/plain_text/1.0.0/90099cb476936b753383ba2ae6ab2eae419b2e87f71cd5189cb9c8e5814d12a3)
# Reusing dataset imdb (/Users/philippschmid/.cache/huggingface/datasets/imdb/plain_text/1.0.0/90099cb476936b753383ba2ae6ab2eae419b2e87f71cd5189cb9c8e5814d12a3)
# Loading cached shuffled indices for dataset at /Users/philippschmid/.cache/huggingface/datasets/imdb/plain_text/1.0.0/90099cb476936b753383ba2ae6ab2eae419b2e87f71cd5189cb9c8e5814d12a3/cache-f7ed38da5ada7a37.arrow
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %% [markdown]
# ## Upload data to sagemaker S3

# %%
import glob
def upload_data_to_s3(dataset=None,prefix='datasets',split_type='train'):
    """helper function with saves the dataset locally using dataset.save_to_disk() and upload its then to s3. """
    
    temp_prefix =f"{prefix}/{split_type}"
    # saves datasets in local directory
    dataset.save_to_disk(f"./{temp_prefix}")
    
    # loops over saved files and uploads them to s3 
    for file in glob.glob(f"./{temp_prefix}/*"):
        sess.upload_data(file, key_prefix=temp_prefix)

    # return s3 url to files for estimator.fit()
    return f"s3://{sess.default_bucket()}/{temp_prefix}"

# %%
prefix = 'datasets/imdb'

training_input_path  = upload_data_to_s3(dataset=train_dataset,prefix=prefix,split_type='train')
test_input_path      = upload_data_to_s3(dataset=test_dataset,prefix=prefix,split_type='test')

print(training_input_path)
print(test_input_path)
# Out:
# s3://sagemaker-eu-central-1-558105141721/datasets/imdb/train
# s3://sagemaker-eu-central-1-558105141721/datasets/imdb/test

# %% [markdown]
# ## Create an local estimator for testing
#
# You run PyTorch training scripts on SageMaker by creating PyTorch Estimators. SageMaker training of your script is invoked when you call fit on a PyTorch Estimator. The following code sample shows how you train a custom PyTorch script `train.py`, passing in three hyperparameters (`epochs`). We are not going to pass any data into sagemaker training job instead it will be downloaded in `train.py`
#
# in sagemaker you can test you training in a "local-mode" by setting your instance_type to `'local'`

# %%
# !pygmentize src/train.py
# Out:
# from transformers import AutoModelForSequenceClassification, Trainer, TrainingArguments
# from sklearn.metrics import accuracy_score, precision_recall_fscore_support
# import random
# import logging
# import sys
# import argparse
# import os
# import torch
#
# if __name__ =='__main__':
#
#     parser = argparse.ArgumentParser()
#
#     # hyperparameters sent by the client are passed as command-line arguments to the script.
#     parser.add_argument('--epochs', type=int, default=3)
#     parser.add_argument('--train-batch-size', type=int, default=32)
#     parser.add_argument('--eval-batch-size', type=int, default=64)
#     parser.add_argument('--warmup_steps', type=int, default=500)
#     parser.add_argument('--model_name', type=str)
#
#     # Data, model, and output directories
#     parser.add_argument('--output-data-dir', type=str, default=os.environ['SM_OUTPUT_DATA_DIR'])
#     parser.add_argument('--model-dir', type=str, default=os.environ['SM_MODEL_DIR'])
#     parser.add_argument('--n_gpus', type=str, default=os.environ['SM_NUM_GPUS'])
#     parser.add_argument('--training_dir', type=str, default=os.environ['SM_CHANNEL_TRAIN'])
#     parser.add_argument('--test_dir', type=str, default=os.environ['SM_CHANNEL_TEST'])
#
#     args, _ = parser.parse_known_args()
#
#     print(args.training_dir)
#     import glob
#     print(glob.glob(args.training_dir+"/*"))
#     # Get datasets
#     train_dataset  = torch.load(os.path.join(args.training_dir, 'train_dataset.pt'))
#     test_dataset  = torch.load(os.path.join(args.test_dir, 'test_dataset.pt'))
#
#     print(len(train_dataset))
#     print(len(test_dataset))
#
#     # compute metrics function for binary classification
#     def compute_metrics(pred):
#         labels = pred.label_ids
#         preds = pred.predictions.argmax(-1)
#         precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')
#         acc = accuracy_score(labels, preds)
#         return {
#             'accuracy': acc,
#             'f1': f1,
#             'precision': precision,
#             'recall': recall
#         }
#
#     # define training args
#     training_args = TrainingArguments(
#         output_dir=args.model_dir,
#         num_train_epochs=args.epochs,
#         per_device_train_batch_size=args.train_batch_size,
#         per_device_eval_batch_size=args.eval_batch_size,
#         warmup_steps=args.warmup_steps,
#         evaluation_strategy='epoch',
#         logging_dir=f'{args.output_data_dir}/logs',
#     )
#
#     # create Trainer instance
#     trainer = Trainer(
#         model=model,
#         args=training_args,
#         compute_metrics=compute_metrics,
#         train_dataset=train_dataset,
#         eval_dataset=test_dataset
#     )
#
#     # train model
#     trainer.train()
#
#     # evaluate model
#     eval_result = trainer.evaluate(eval_dataset=test_dataset)
#
#     # writes eval result to file which can be accessed later in s3 ouput
#     with open(os.path.join(args.output_data_dir, "eval_results.txt"), "w") as writer:
#         print(f"***** Eval results *****")
#         for key, value in sorted(eval_result.items()):
#             writer.write(f"{key} = {value}\n")
#
#      # Saves the model to s3
#     trainer.save_model(args.model_dir)

# %% [markdown]
# ## Importing custom sdk-extension for HuggingFace

# %%
training_input_path  = 's3://sagemaker-eu-central-1-558105141721/datasets/imdb/small/train'
test_input_path      = 's3://sagemaker-eu-central-1-558105141721/datasets/imdb/small/test'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from huggingface.estimator import HuggingFace

# %% [markdown]
# ## Create an local Estimator
#
# The following code sample shows how you train a custom HuggingFace script `train.py`, passing in three hyperparameters (`epochs`,`train_batch_size`,`model_name`). We are not going to pass any data into sagemaker training job instead it will be downloaded in `train.py`

# %%
huggingface_estimator = HuggingFace(entry_point='train.py',
                            base_job_name='huggingface',
                            instance_type='local',
                            instance_count=1,
                            role=role,
                            framework_version={'transformers':'4.1.1','datasets':'1.1.3'},
                            py_version='py3',
                            hyperparameters = {'epochs': 1,
                                               'train_batch_size': 32,
                                               'model_name':'distilbert-base-uncased'
                                                })

# %%
huggingface_estimator.image_uri
# Out:
# '558105141721.dkr.ecr.eu-central-1.amazonaws.com/huggingface-training:0.0.1-cpu-transformers4.1.1-datasets1.1.3'

# %%
huggingface_estimator.fit({'train': training_input_path, 'test': test_input_path})
# Out:
# Creating vjrxuebgqp-algo-1-7vnys ...
# Attaching to vjrxuebgqp-algo-1-7vnys2mdone
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:29,768 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:29,771 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:29,789 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:29,803 sagemaker_pytorch_container.training INFO     Invoking user training script.
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:29,966 botocore.credentials INFO     Found credentials in environment variables.
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:30,238 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:30,259 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:30,278 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:30,294 sagemaker-training-toolkit INFO     Invoking user script
# vjrxuebgqp-algo-1-7vnys |
# vjrxuebgqp-algo-1-7vnys | Training Env:
# vjrxuebgqp-algo-1-7vnys |
# vjrxuebgqp-algo-1-7vnys | {
# vjrxuebgqp-algo-1-7vnys |     "additional_framework_parameters": {},
# vjrxuebgqp-algo-1-7vnys |     "channel_input_dirs": {
# vjrxuebgqp-algo-1-7vnys |         "train": "/opt/ml/input/data/train",
# vjrxuebgqp-algo-1-7vnys |         "test": "/opt/ml/input/data/test"
# vjrxuebgqp-algo-1-7vnys |     },
# vjrxuebgqp-algo-1-7vnys |     "current_host": "algo-1-7vnys",
# vjrxuebgqp-algo-1-7vnys |     "framework_module": "sagemaker_pytorch_container.training:main",
# vjrxuebgqp-algo-1-7vnys |     "hosts": [
# vjrxuebgqp-algo-1-7vnys |         "algo-1-7vnys"
# vjrxuebgqp-algo-1-7vnys |     ],
# vjrxuebgqp-algo-1-7vnys |     "hyperparameters": {
# vjrxuebgqp-algo-1-7vnys |         "epochs": 1,
# vjrxuebgqp-algo-1-7vnys |         "train_batch_size": 32,
# vjrxuebgqp-algo-1-7vnys |         "model_name": "distilbert-base-uncased"
# vjrxuebgqp-algo-1-7vnys |     },
# vjrxuebgqp-algo-1-7vnys |     "input_config_dir": "/opt/ml/input/config",
# vjrxuebgqp-algo-1-7vnys |     "input_data_config": {
# vjrxuebgqp-algo-1-7vnys |         "train": {
# vjrxuebgqp-algo-1-7vnys |             "TrainingInputMode": "File"
# vjrxuebgqp-algo-1-7vnys |         },
# vjrxuebgqp-algo-1-7vnys |         "test": {
# vjrxuebgqp-algo-1-7vnys |             "TrainingInputMode": "File"
# vjrxuebgqp-algo-1-7vnys |         }
# vjrxuebgqp-algo-1-7vnys |     },
# vjrxuebgqp-algo-1-7vnys |     "input_dir": "/opt/ml/input",
# vjrxuebgqp-algo-1-7vnys |     "is_master": true,
# vjrxuebgqp-algo-1-7vnys |     "job_name": "huggingface-2020-12-27-17-08-21-833",
# vjrxuebgqp-algo-1-7vnys |     "log_level": 20,
# vjrxuebgqp-algo-1-7vnys |     "master_hostname": "algo-1-7vnys",
# vjrxuebgqp-algo-1-7vnys |     "model_dir": "/opt/ml/model",
# vjrxuebgqp-algo-1-7vnys |     "module_dir": "s3://sagemaker-eu-central-1-558105141721/huggingface-2020-12-27-17-08-21-833/source/sourcedir.tar.gz",
# vjrxuebgqp-algo-1-7vnys |     "module_name": "train",
# vjrxuebgqp-algo-1-7vnys |     "network_interface_name": "eth0",
# vjrxuebgqp-algo-1-7vnys |     "num_cpus": 4,
# vjrxuebgqp-algo-1-7vnys |     "num_gpus": 0,
# vjrxuebgqp-algo-1-7vnys |     "output_data_dir": "/opt/ml/output/data",
# vjrxuebgqp-algo-1-7vnys |     "output_dir": "/opt/ml/output",
# vjrxuebgqp-algo-1-7vnys |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# vjrxuebgqp-algo-1-7vnys |     "resource_config": {
# vjrxuebgqp-algo-1-7vnys |         "current_host": "algo-1-7vnys",
# vjrxuebgqp-algo-1-7vnys |         "hosts": [
# vjrxuebgqp-algo-1-7vnys |             "algo-1-7vnys"
# vjrxuebgqp-algo-1-7vnys |         ]
# vjrxuebgqp-algo-1-7vnys |     },
# vjrxuebgqp-algo-1-7vnys |     "user_entry_point": "train.py"
# vjrxuebgqp-algo-1-7vnys | }
# vjrxuebgqp-algo-1-7vnys |
# vjrxuebgqp-algo-1-7vnys | Environment variables:
# vjrxuebgqp-algo-1-7vnys |
# vjrxuebgqp-algo-1-7vnys | SM_HOSTS=["algo-1-7vnys"]
# vjrxuebgqp-algo-1-7vnys | SM_NETWORK_INTERFACE_NAME=eth0
# vjrxuebgqp-algo-1-7vnys | SM_HPS={"epochs":1,"model_name":"distilbert-base-uncased","train_batch_size":32}
# vjrxuebgqp-algo-1-7vnys | SM_USER_ENTRY_POINT=train.py
# vjrxuebgqp-algo-1-7vnys | SM_FRAMEWORK_PARAMS={}
# vjrxuebgqp-algo-1-7vnys | SM_RESOURCE_CONFIG={"current_host":"algo-1-7vnys","hosts":["algo-1-7vnys"]}
# vjrxuebgqp-algo-1-7vnys | SM_INPUT_DATA_CONFIG={"test":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"}}
# vjrxuebgqp-algo-1-7vnys | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# vjrxuebgqp-algo-1-7vnys | SM_CHANNELS=["test","train"]
# vjrxuebgqp-algo-1-7vnys | SM_CURRENT_HOST=algo-1-7vnys
# vjrxuebgqp-algo-1-7vnys | SM_MODULE_NAME=train
# vjrxuebgqp-algo-1-7vnys | SM_LOG_LEVEL=20
# vjrxuebgqp-algo-1-7vnys | SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# vjrxuebgqp-algo-1-7vnys | SM_INPUT_DIR=/opt/ml/input
# vjrxuebgqp-algo-1-7vnys | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# vjrxuebgqp-algo-1-7vnys | SM_OUTPUT_DIR=/opt/ml/output
# vjrxuebgqp-algo-1-7vnys | SM_NUM_CPUS=4
# vjrxuebgqp-algo-1-7vnys | SM_NUM_GPUS=0
# vjrxuebgqp-algo-1-7vnys | SM_MODEL_DIR=/opt/ml/model
# vjrxuebgqp-algo-1-7vnys | SM_MODULE_DIR=s3://sagemaker-eu-central-1-558105141721/huggingface-2020-12-27-17-08-21-833/source/sourcedir.tar.gz
# vjrxuebgqp-algo-1-7vnys | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1-7vnys","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1-7vnys"],"hyperparameters":{"epochs":1,"model_name":"distilbert-base-uncased","train_batch_size":32},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"TrainingInputMode":"File"},"train":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"huggingface-2020-12-27-17-08-21-833","log_level":20,"master_hostname":"algo-1-7vnys","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-central-1-558105141721/huggingface-2020-12-27-17-08-21-833/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-7vnys","hosts":["algo-1-7vnys"]},"user_entry_point":"train.py"}
# vjrxuebgqp-algo-1-7vnys | SM_USER_ARGS=["--epochs","1","--model_name","distilbert-base-uncased","--train_batch_size","32"]
# vjrxuebgqp-algo-1-7vnys | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# vjrxuebgqp-algo-1-7vnys | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# vjrxuebgqp-algo-1-7vnys | SM_CHANNEL_TEST=/opt/ml/input/data/test
# vjrxuebgqp-algo-1-7vnys | SM_HP_EPOCHS=1
# vjrxuebgqp-algo-1-7vnys | SM_HP_TRAIN_BATCH_SIZE=32
# vjrxuebgqp-algo-1-7vnys | SM_HP_MODEL_NAME=distilbert-base-uncased
# vjrxuebgqp-algo-1-7vnys | PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# vjrxuebgqp-algo-1-7vnys |
# vjrxuebgqp-algo-1-7vnys | Invoking script with the following command:
# vjrxuebgqp-algo-1-7vnys |
# vjrxuebgqp-algo-1-7vnys | /opt/conda/bin/python train.py --epochs 1 --model_name distilbert-base-uncased --train_batch_size 32
# vjrxuebgqp-algo-1-7vnys |
# vjrxuebgqp-algo-1-7vnys |
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:33,574 - __main__ - INFO -  loaded train_dataset length is: 2000
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:33,574 - __main__ - INFO -  loaded test_dataset length is: 150
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:33,938 - filelock - INFO - Lock 140437597566176 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:34,280 - filelock - INFO - Lock 140437597566176 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:34,615 - filelock - INFO - Lock 140437597568248 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:08:48,068 - filelock - INFO - Lock 140437597568248 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# Downloading: 100%|██████████| 442/442 [00:00<00:00, 297kB/s]
# Downloading: 100%|██████████| 268M/268M [00:13<00:00, 20.2MB/s]
# vjrxuebgqp-algo-1-7vnys | Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# vjrxuebgqp-algo-1-7vnys | - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# vjrxuebgqp-algo-1-7vnys | - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# vjrxuebgqp-algo-1-7vnys | Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# vjrxuebgqp-algo-1-7vnys | You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/63 [00:00<?, ?it/s]/opt/conda/lib/python3.6/site-packages/datasets/arrow_dataset.py:850: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /codebuild/output/src062189915/src/torch/csrc/utils/tensor_numpy.cpp:141.)
# vjrxuebgqp-algo-1-7vnys |   return torch.tensor(x, **format_kwargs)
# vjrxuebgqp-algo-1-7vnys |
# vjrxuebgqp-algo-1-7vnys | 2020-12-27 17:09:11,557 sagemaker-training-toolkit ERROR    ExecuteUserScriptError:
# vjrxuebgqp-algo-1-7vnys | Command "/opt/conda/bin/python train.py --epochs 1 --model_name distilbert-base-uncased --train_batch_size 32"
# Downloading: 100%|ââââââââââ| 442/442 [00:00<00:00, 297kB/s]
# Downloading: 100%|ââââââââââ| 268M/268M [00:13<00:00, 20.2MB/s]
# vjrxuebgqp-algo-1-7vnys | Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias']
# vjrxuebgqp-algo-1-7vnys | - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# vjrxuebgqp-algo-1-7vnys | - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# vjrxuebgqp-algo-1-7vnys | Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# vjrxuebgqp-algo-1-7vnys | You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/63 [00:00<?, ?it/s]/opt/conda/lib/python3.6/site-packages/datasets/arrow_dataset.py:850: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /codebuild/output/src062189915/src/torch/csrc/utils/tensor_numpy.cpp:141.)
# vjrxuebgqp-algo-1-7vnys |   return torch.tensor(x, **format_kwargs)
# vjrxuebgqp-algo-1-7vnys exited with code 1
# Aborting on container exit...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     236         try:
# --> 237             _stream_output(process)
#     238         except RuntimeError as e:
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/local/image.py in _stream_output(process)
#     886     if exit_code != 0:
# --> 887         raise RuntimeError("Process exited with code: %s" % exit_code)
#     888
#
# RuntimeError: Process exited with code: 1
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-90-e7ad92514db5> in <module>
# ----> 1 huggingface_estimator.fit({'train': training_input_path, 'test': test_input_path})
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     654         self._prepare_for_training(job_name=job_name)
#     655
# --> 656         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#     657         self.jobs.append(self.latest_training_job)
#     658         if wait:
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    1417         """
#    1418         train_args = cls._get_train_args(estimator, inputs, experiment_config)
# -> 1419         estimator.sagemaker_session.train(**train_args)
#    1420
#    1421         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, profiler_rule_configs, profiler_config)
#     560         LOGGER.info("Creating training-job with name: %s", job_name)
#     561         LOGGER.debug("train request: %s", json.dumps(train_request, indent=4))
# --> 562         self.sagemaker_client.create_training_job(**train_request)
#     563
#     564     def _get_train_request(  # noqa: C901
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/local/local_session.py in create_training_job(self, TrainingJobName, AlgorithmSpecification, OutputDataConfig, ResourceConfig, InputDataConfig, **kwargs)
#     184         hyperparameters = kwargs["HyperParameters"] if "HyperParameters" in kwargs else {}
#     185         logger.info("Starting training job")
# --> 186         training_job.start(InputDataConfig, OutputDataConfig, hyperparameters, TrainingJobName)
#     187
#     188         LocalSagemakerClient._training_jobs[TrainingJobName] = training_job
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/local/entities.py in start(self, input_data_config, output_data_config, hyperparameters, job_name)
#     218         self.state = self._TRAINING
#     219
# --> 220         self.model_artifacts = self.container.train(
#     221             input_data_config, output_data_config, hyperparameters, job_name
#     222         )
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     240             # which contains the exit code and append the command line to it.
#     241             msg = "Failed to run: %s, %s" % (compose_command, str(e))
# --> 242             raise RuntimeError(msg)
#     243         finally:
#     244             artifacts = self.retrieve_artifacts(compose_data, output_data_config, job_name)
#
# RuntimeError: Failed to run: ['docker-compose', '-f', '/private/var/folders/jj/dzns9hc55db1vmfsjvrh9n8m0000gp/T/tmp12pz5tan/docker-compose.yaml', 'up', '--build', '--abort-on-container-exit'], Process exited with code: 1

# %% [markdown]
# ## Create an Estimator
#
# The following code sample shows how you train a custom HuggingFace script `train.py`, passing in three hyperparameters (`epochs`,`train_batch_size`,`model_name`). We are not going to pass any data into sagemaker training job instead it will be downloaded in `train.py`

# %%
from huggingface.estimator import HuggingFace


huggingface_estimator = HuggingFace(entry_point='train.py',
                            source_dir='.',
                            sagemaker_session=sess,
                            base_job_name='huggingface-sdk-extension',
                            instance_type='ml.p3.2xlarge',
                            instance_count=1,
                            role=role,
                            framework_version={'transformers':'4.1.1','datasets':'1.1.3'},
                            py_version='py3',
                            hyperparameters = {'epochs': 1,
                                               'train_batch_size': 32,
                                               'model_name':'distilbert-base-uncased'
                                                })

# %%
huggingface_estimator.fit({'train': training_input_path, 'test': test_input_path})
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-24-e7ad92514db5> in <module>
# ----> 1 huggingface_estimator.fit({'train': training_input_path, 'test': test_input_path})
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     654         self._prepare_for_training(job_name=job_name)
#     655
# --> 656         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#     657         self.jobs.append(self.latest_training_job)
#     658         if wait:
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    1417         """
#    1418         train_args = cls._get_train_args(estimator, inputs, experiment_config)
# -> 1419         estimator.sagemaker_session.train(**train_args)
#    1420
#    1421         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, profiler_rule_configs, profiler_config)
#     560         LOGGER.info("Creating training-job with name: %s", job_name)
#     561         LOGGER.debug("train request: %s", json.dumps(train_request, indent=4))
# --> 562         self.sagemaker_client.create_training_job(**train_request)
#     563
#     564     def _get_train_request(  # noqa: C901
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the CreateTrainingJob operation: No S3 objects found under S3 URL "s3://sagemaker-eu-central-1-558105141721/datasets/imdb/train" given in input data source. Please ensure that the bucket exists in the selected region (eu-central-1), that objects exist under that S3 prefix, and that the role "arn:aws:iam::558105141721:role/SageMakerRole" has "s3:ListBucket" permissions on bucket "sagemaker-eu-central-1-558105141721".

# %% [markdown]
# ## Create an Estimator using spot instances
#
# The following code sample shows how you train a custom HuggingFace script `train.py`, passing in three hyperparameters (`epochs`,`train_batch_size`,`model_name`). We are not going to pass any data into sagemaker training job instead it will be downloaded in `train.py`

# %%
from huggingface.estimator import HuggingFace


huggingface_estimator = HuggingFace(entry_point='train.py',
                            source_dir='.',
                            sagemaker_session=sess,
                            use_spot_instances=True,
                            max_wait=3600, # This should be equal to or greater than max_run in seconds'
                            max_run=1000,
                            base_job_name='huggingface-sdk-extension',
                            instance_type='ml.p3.2xlarge',
                            instance_count=1,
                            role=role,
                            framework_version={'transformers':'4.1.1','datasets':'1.1.3'},
                            py_version='py3',
                            hyperparameters = {'epochs': 1,
                                               'train_batch_size': 32,
                                               'model_name':'distilbert-base-uncased'
                                                })

# %%
huggingface_estimator.fit({'train': training_input_path, 'test': test_input_path})
# Out:
# 2020-12-27 15:25:53 Starting - Starting the training job...
# 2020-12-27 15:26:17 Starting - Launching requested ML instancesProfilerReport-1609082750: InProgress
# ......
# 2020-12-27 15:27:17 Starting - Preparing the instances for training.........
# 2020-12-27 15:28:40 Downloading - Downloading input data
# 2020-12-27 15:28:40 Training - Downloading the training image.....................
# 2020-12-27 15:32:21 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-12-27 15:32:15,198 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2020-12-27 15:32:15,221 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-12-27 15:32:18,249 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-12-27 15:32:18,802 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "train_batch_size": 32,
#         "model_name": "distilbert-base-uncased",
#         "epochs": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "huggingface-sdk-extension-2020-12-27-15-25-50-506",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-central-1-558105141721/huggingface-sdk-extension-2020-12-27-15-25-50-506/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":1,"model_name":"distilbert-base-uncased","train_batch_size":32}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-central-1-558105141721/huggingface-sdk-extension-2020-12-27-15-25-50-506/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1,"model_name":"distilbert-base-uncased","train_batch_size":32},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"huggingface-sdk-extension-2020-12-27-15-25-50-506","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-central-1-558105141721/huggingface-sdk-extension-2020-12-27-15-25-50-506/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--epochs","1","--model_name","distilbert-base-uncased","--train_batch_size","32"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_TRAIN_BATCH_SIZE=32
# SM_HP_MODEL_NAME=distilbert-base-uncased
# SM_HP_EPOCHS=1
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python train.py --epochs 1 --model_name distilbert-base-uncased --train_batch_size 32
#
#
# 2020-12-27 15:32:22,212 - __main__ - INFO -  loaded train_dataset length is: 2000
# 2020-12-27 15:32:22,213 - __main__ - INFO -  loaded test_dataset length is: 150
# 2020-12-27 15:32:22,511 - filelock - INFO - Lock 140208028323288 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2020-12-27 15:32:22,796 - filelock - INFO - Lock 140208028323288 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2020-12-27 15:32:23,079 - filelock - INFO - Lock 140208028162648 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# 2020-12-27 15:32:28,027 - filelock - INFO - Lock 140208028162648 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# [2020-12-27 15:32:33.312 algo-1:25 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-12-27 15:32:33.312 algo-1:25 INFO hook.py:193] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-12-27 15:32:33.312 algo-1:25 INFO hook.py:238] Saving to /opt/ml/output/tensors
# [2020-12-27 15:32:33.312 algo-1:25 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2020-12-27 15:32:33.329 algo-1:25 INFO hook.py:398] Monitoring the collections: losses
# [2020-12-27 15:32:33.329 algo-1:25 INFO hook.py:461] Hook is writing from the hook with pid: 25
#
# [2020-12-27 15:32:34.658 algo-1:25 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert.transformer BaseModelOutput
# [2020-12
# #015100%|██████████| 3/3 [00:00<00:00,  5.59it/s]#033[A
# #015                                             #033[A#015                                               #015#015100%|██████████| 63/63 [00:33<00:00,  2.30it/s]#015100%|██████████| 63/63 [00:33<00:00,  1.86it/s]
# #015  0%|          | 0/3 [00:00<?, ?it/s]#015 67%|██████▋   | 2/3 [00:00<00:00,  7.23it/s]#015100%|██████████| 3/3 [00:00<00:00,  5.55it/s]#015100%|██████████| 3/3 [00:00<00:00,  4.65it/s]
# 2020-12-27 15:33:08,975 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# 2020-12-27 15:33:22 Uploading - Uploading generated training model
# 2020-12-27 15:33:48 Completed - Training job completed
# Training seconds: 316
# Billable seconds: 95
# Managed Spot Training savings: 69.9%

# %% [markdown]
# # Create an Estimator with Metric tracking
#
# [Metric Documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/training-metrics.html)
#
# To find a metric, SageMaker searches the logs that your algorithm emits and finds logs that match the regular expression that you specify for that metric.
#
# Defining Training Metrics (SageMaker Python SDK)
# Define the metrics that you want to send to CloudWatch by specifying a list of metric names and regular expressions as the metric_definitions argument when you initialize an Estimator object. For example, if you want to monitor both the train:error and validation:error metrics in CloudWatch, your Estimator initialization would look like the following:
# ```python
#    estimator = Estimator(image_name=ImageName,
#                 role='SageMakerRole', train_instance_count=1,
#                 train_instance_type='ml.c4.xlarge',
#                 train_instance_type='ml.c4.xlarge',
#                 k=10,
#                 sagemaker_session=sagemaker_session,
#                 metric_definitions=[
#                    {'Name': 'train:error', 'Regex': 'Train_error=(.*?);'},
#                    {'Name': 'validation:error', 'Regex': 'Valid_error=(.*?);'}
#                 ]
#             )
# ```
#
# In the regex for the train:error metric defined above, the first part of the regex finds the exact text `"Train_error="`, and the expression `(.*?);` captures zero or more of any character until the first `;` semicolon character.
#
# For more information about training by using Amazon SageMaker Python SDK estimators, see https://github.com/aws/sagemaker-python-sdk#sagemaker-python-sdk-overview.

# %%
from huggingface.estimator import HuggingFace


huggingface_estimator = HuggingFace(entry_point='train.py',
                            source_dir='.',
                            sagemaker_session=sess,
                            use_spot_instances=True,
                            max_wait=4600, # This should be equal to or greater than max_run in seconds'
                            max_run=3600,
                            base_job_name='huggingface-sdk-extension',
                            instance_type='ml.p3.2xlarge',
                            instance_count=1,
                            role=role,
                            framework_version={'transformers':'4.1.1','datasets':'1.1.3'},
                            py_version='py3',
                            metric_definitions=[
                                 {'Name': 'validation:eval_loss', 'Regex':"'eval_loss': (.*?),"},
                                 {'Name': 'validation:eval_accuracy', 'Regex': "'eval_accuracy': (.*?),"},
                                 {'Name': 'validation:eval_f1', 'Regex': "'eval_f1': (.*?),"},
                                 {'Name': 'validation:eval_precision', 'Regex': "'eval_precision': (.*?),"},
                                 {'Name': 'validation:eval_recall', 'Regex': "'eval_recall': (.*?),"}],
                            hyperparameters = {'epochs': 3,
                                               'train_batch_size': 16,
                                               'model_name':'distilbert-base-uncased'})

# %%
huggingface_estimator.fit({'train': training_input_path, 'test': test_input_path})
# Out:
# 2020-12-28 10:00:51 Starting - Starting the training job...
# 2020-12-28 10:01:14 Starting - Launching requested ML instancesProfilerReport-1609149606: InProgress
# ......
# 2020-12-28 10:02:15 Starting - Preparing the instances for training.........
# 2020-12-28 10:03:42 Downloading - Downloading input data
# 2020-12-28 10:03:42 Training - Downloading the training image.....................
# 2020-12-28 10:07:19 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-12-28 10:07:14,008 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2020-12-28 10:07:14,033 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-12-28 10:07:17,073 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-12-28 10:07:19,786 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "train_batch_size": 16,
#         "model_name": "distilbert-base-uncased",
#         "epochs": 3
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "huggingface-sdk-extension-2020-12-28-10-00-06-104",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-central-1-558105141721/huggingface-sdk-extension-2020-12-28-10-00-06-104/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":3,"model_name":"distilbert-base-uncased","train_batch_size":16}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-central-1-558105141721/huggingface-sdk-extension-2020-12-28-10-00-06-104/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":3,"model_name":"distilbert-base-uncased","train_batch_size":16},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"huggingface-sdk-extension-2020-12-28-10-00-06-104","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-central-1-558105141721/huggingface-sdk-extension-2020-12-28-10-00-06-104/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--epochs","3","--model_name","distilbert-base-uncased","--train_batch_size","16"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_TRAIN_BATCH_SIZE=16
# SM_HP_MODEL_NAME=distilbert-base-uncased
# SM_HP_EPOCHS=3
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python train.py --epochs 3 --model_name distilbert-base-uncased --train_batch_size 16
#
#
# 2020-12-28 10:07:23,841 - __main__ - INFO -  loaded train_dataset length is: 25000
# 2020-12-28 10:07:23,841 - __main__ - INFO -  loaded test_dataset length is: 10000
# 2020-12-28 10:07:24,151 - filelock - INFO - Lock 140402601687864 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2020-12-28 10:07:24,436 - filelock - INFO - Lock 140402601687864 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2020-12-28 10:07:24,721 - filelock - INFO - Lock 140402601296784 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# 2020-12-28 10:07:29,909 - filelock - INFO - Lock 140402601296784 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# [2020-12-28 10:07:35.306 algo-1:30 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-12-28 10:07:35.306 algo-1:30 INFO hook.py:193] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-12-28 10:07:35.306 algo-1:30 INFO hook.py:238] Saving to /opt/ml/output/tensors
# [2020-12-28 10:07:35.306 algo-1:30 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2020-12-28 10:07:35.325 algo-1:30 INFO hook.py:398] Monitoring the collections: losses
# [2020-12-28 10:07:35.325 algo-1:30 INFO hook.py:461] Hook is writing from the hook with pid: 30
#
# [2020-12-28 10:07:36.661 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert.transformer BaseModelOutput
# [2020-12-28 10:07:36.661 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert BaseModelOutput
# [2020-12-28 10:07:36.746 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:DistilBertForSequenceClassification SequenceClassifierOutput
# {'loss': 0.3612448425292969, 'learning_rate': 5e-05, 'epoch': 0.639386189258312}
# [2020-12-28 10:11:54.596 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert.transformer BaseModelOutput
# [2020-12-28 10:11:54.596 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert BaseModelOutput
# [2020-12-28 10:11:54.597 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:DistilBertForSequenceClassification SequenceClassifierOutput
# {'eval_loss': 0.23605793714523315, 'eval_accuracy': 0.9109, 'eval_f1': 0.9154247745609871, 'eval_precision': 0.8745012694958288, 'eval_recall': 0.9603664608643696, 'epoch': 1.0}
# [2020-12-28 10:15:35.442 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert.transformer BaseModelOutput
# [2020-12-28 10:15:35.443 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert BaseModelOutput
# [2020-12-28 10:15:35.444 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:DistilBertForSequenceClassification SequenceClassifierOutput
# {'loss': 0.21001081848144532, 'learning_rate': 3.645720476706392e-05, 'epoch': 1.278772378516624}
# [2020-12-28 10:19:54.511 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert.transformer BaseModelOutput
# [2020-12-28 10:19:54.511 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert BaseModelOutput
# [2020-12-28 10:19:54.513 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:DistilBertForSequenceClassification SequenceClassifierOutput
# {'loss': 0.1606374969482422, 'learning_rate': 2.2914409534127847e-05, 'epoch': 1.918158567774936}
# {'eval_loss': 0.21505700051784515, 'eval_accuracy': 0.9225, 'eval_f1': 0.9254879338525142, 'eval_precision': 0.8946096654275093, 'eval_recall': 0.9585739892451702, 'epoch': 2.0}
# [2020-12-28 10:23:37.542 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert.transformer BaseModelOutput
# [2020-12-28 10:23:37.542 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert BaseModelOutput
# [2020-12-28 10:23:37.543 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:DistilBertForSequenceClassification SequenceClassifierOutput
# {'loss': 0.07959130096435547, 'learning_rate': 9.371614301191767e-06, 'epoch': 2.557544757033248}
# [2020-12-28 10:27:55.795 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert.transformer BaseModelOutput
# [2020-12-28 10:27:55.795 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert BaseModelOutput
# [2020-12-28 10:27:55.796 algo-1:30 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:DistilBertForSequenceClassification SequenceClassifierOutput
# {
# #015 82%|████████▏ | 128/157 [00:35<00:08,  3.55it/s]#033[A
# #015 82%|████████▏ | 129/157 [00:36<00:07,  3.55it/s]#033[A
# #015 83%|████████▎ | 130/157 [00:36<00:07,  3.55it/s]#033[A
# #015 83%|████████▎ | 131/157 [00:36<00:07,  3.55it/s]#033[A
# #015 84%|████████▍ | 132/157 [00:36<00:07,  3.55it/s]#033[A
# #015 85%|████████▍ | 133/157 [00:37<00:06,  3.55it/s]#033[A
# #015 85%|████████▌ | 134/157 [00:37<00:06,  3.55it/s]#033[A
# #015 86%|████████▌ | 135/157 [00:37<00:06,  3.55it/s]#033[A
# #015 87%|████████▋ | 136/157 [00:38<00:05,  3.55it/s]#033[A
# #015 87%|████████▋ | 137/157 [00:38<00:05,  3.55it/s]#033[A
# #015 88%|████████▊ | 138/157 [00:38<00:05,  3.54it/s]#033[A
# #015 89%|████████▊ | 139/157 [00:38<00:05,  3.55it/s]#033[A
# #015 89%|████████▉ | 140/157 [00:39<00:04,  3.55it/s]#033[A
# #015 90%|████████▉ | 141/157 [00:39<00:04,  3.54it/s]#033[A
# #015 90%|█████████ | 142/157 [00:39<00:04,  3.53it/s]#033[A
# #015 91%|█████████ | 143/157 [00:40<00:03,  3.54it/s]#033[A
# #015 92%|█████████▏| 144/157 [00:40<00:03,  3.55it/s]#033[A
# #015 92%|█████████▏| 145/157 [00:40<00:03,  3.55it/s]#033[A
# #015 93%|█████████▎| 146/157 [00:40<00:03,  3.55it/s]#033[A
# #015 94%|█████████▎| 147/157 [00:41<00:02,  3.55it/s]#033[A
# #015 94%|█████████▍| 148/157 [00:41<00:02,  3.54it/s]#033[A
# #015 95%|█████████▍| 149/157 [00:41<00:02,  3.55it/s]#033[A
# #015 96%|█████████▌| 150/157 [00:41<00:01,  3.55it/s]#033[A
# #015 96%|█████████▌| 151/157 [00:42<00:01,  3.54it/s]#033[A
# #015 97%|█████████▋| 152/157 [00:42<00:01,  3.55it/s]#033[A
# #015 97%|█████████▋| 153/157 [00:42<00:01,  3.55it/s]#033[A
# #015 98%|█████████▊| 154/157 [00:43<00:00,  3.55it/s]#033[A
# #015 99%|█████████▊| 155/157 [00:43<00:00,  3.55it/s]#033[A
# #015 99%|█████████▉| 156/157 [00:43<00:00,  3.55it/s]#033[A
# #015100%|██████████| 157/157 [00:43<00:00,  3.55it/s]#033[A#015                                                   #015
# #015                                                 #015#033[A#015100%|██████████| 2346/2346 [22:26<00:00,  2.46it/s]
# #015100%|██████████| 157/157 [00:44<00:00,  3.55it/s]#033[A
# #015                                                 #033[A#015                                                   #015#015100%|██████████| 2346/2346 [22:26<00:00,  2.46it/s]#015100%|██████████| 2346/2346 [22:26<00:00,  1.74it/s]
 [00:14<00:29,  3.55it/s]#015 34%|███▍      | 53/157 [00:14<00:29,  3.55it/s]#015 34%|███▍      | 54/157 [00:14<00:29,  3.55it/s]#015 35%|███▌      | 55/157 [00:15<00:28,  3.55it/s]#015 36%|███▌      | 56/157 [00:15<00:28,  3.55it/s]#015 36%|███▋      | 57/157 [00:15<00:28,  3.55it/s]#015 37%|███▋      | 58/157 [00:16<00:27,  3.55it/s]#015 38%|███▊      | 59/157 [00:16<00:27,  3.55it/s]#015 38%|███▊      | 60/157 [00:16<00:27,  3.54it/s]#015 39%|███▉      | 61/157 [00:16<00:27,  3.54it/s]#015 39%|███▉      | 62/157 [00:17<00:26,  3.55it/s]#015 40%|████      | 63/157 [00:17<00:26,  3.55it/s]#015 41%|████      | 64/157 [00:17<00:26,  3.55it/s]#015 41%|████▏     | 65/157 [00:18<00:25,  3.55it/s]#015 42%|████▏     | 66/157 [00:18<00:25,  3.55it/s]#015 43%|████▎     | 67/157 [00:18<00:25,  3.55it/s]#015 43%|████▎     | 68/157 [00:18<00:25,  3.55it/s]#015 44%|████▍     | 69/157 [00:19<00:24,  3.54it/s]#015 45%|████▍     | 70/157 [00:19<00:24,  3.54it/s]#015 45%|████▌     | 71/157 [00:19<00:24,  3.55it/s]#015 46%|████▌     | 72/157 [00:20<00:23,  3.55it/s]#015 46%|████▋     | 73/157 [00:20<00:23,  3.55it/s]#015 47%|████▋     | 74/157 [00:20<00:23,  3.55it/s]#015 48%|████▊     | 75/157 [00:20<00:23,  3.55it/s]#015 48%|████▊     | 76/157 [00:21<00:22,  3.55it/s]#015 49%|████▉     | 77/157 [00:21<00:22,  3.55it/s]#015 50%|████ ...
# 2020-12-28 10:30:51 Uploading - Uploading generated training model
# 2020-12-28 10:37:39 Completed - Training job completed
# Training seconds: 2049
# Billable seconds: 615
# Managed Spot Training savings: 70.0%

# %% [markdown]
# ## Plot results

# %%
import matplotlib
import pandas as pd
# %matplotlib inline

def plot_result(estimator,metrics='all'):
    """plots tracked result metrics and returns dataframe of it. """
    df = estimator.training_job_analytics.dataframe()
    dx = df.pivot(index='timestamp', columns='metric_name', values='value').reset_index().rename_axis(None, axis=1)
    if metrics == 'all':
        dx.plot(kind='line', figsize=(12,5), x='timestamp')
    else:
        if isinstance(metrics,list):
            metrics.append('timestamp')
            dx[metrics].plot(kind='line', figsize=(12,5), x='timestamp')
        else:
            dx[[metrics,'timestamp']].plot(kind='line', figsize=(12,5), x='timestamp')
    return dx

# %% [markdown]
# ### plot all metrics

# %%
plot_result(huggingface_estimator)
# Out:
#    timestamp  validation:eval_accuracy  validation:eval_f1  \
# 0        0.0                    0.9109            0.915425
# 1      420.0                    0.9225            0.925488
# 2      900.0                    0.9323            0.932804
#
#    validation:eval_loss  validation:eval_precision  validation:eval_recall
# 0              0.236058                   0.874501                0.960366
# 1              0.215057                   0.894610                0.958574
# 2              0.251635                   0.929759                0.935869

# %% [markdown]
# ### plot 1 metric

# %%
plot_result(huggingface_estimator,'validation:eval_f1')
# Out:
#    timestamp  validation:eval_accuracy  validation:eval_f1  \
# 0        0.0                    0.9109            0.915425
# 1      420.0                    0.9225            0.925488
# 2      900.0                    0.9323            0.932804
#
#    validation:eval_loss  validation:eval_precision  validation:eval_recall
# 0              0.236058                   0.874501                0.960366
# 1              0.215057                   0.894610                0.958574
# 2              0.251635                   0.929759                0.935869

# %% [markdown]
# ### plot mutliple metrics

# %%
plot_result(huggingface_estimator,['validation:eval_recall','validation:eval_precision'])
# Out:
#    timestamp  validation:eval_accuracy  validation:eval_f1  \
# 0        0.0                    0.9109            0.915425
# 1      420.0                    0.9225            0.925488
# 2      900.0                    0.9323            0.932804
#
#    validation:eval_loss  validation:eval_precision  validation:eval_recall
# 0              0.236058                   0.874501                0.960366
# 1              0.215057                   0.894610                0.958574
# 2              0.251635                   0.929759                0.935869

# %% [markdown]
# # Estimator Parameters

# %% [markdown]
# ### Get S3 url for model data

# %%
huggingface_estimator.model_data
# Out:
# 's3://sagemaker-eu-central-1-558105141721/huggingface-sdk-extension-2020-12-27-15-25-50-506/output/model.tar.gz'

# %% [markdown]
# ### Get latest training job name

# %%
huggingface_estimator.latest_training_job.name
# Out:
# 'huggingface-sdk-extension-2020-12-27-15-25-50-506'

# %% [markdown]
# ### Attach to old estimator
#
# e.g. to get model data

# %%
old_job_name='huggingface-sdk-extension-2020-12-27-15-25-50-506'

# %%
from sagemaker.estimator import Estimator

# %%
huggingface_estimator_loaded = Estimator.attach(old_job_name)
# Out:
# 2020-12-27 15:34:03 Starting - Preparing the instances for training
# 2020-12-27 15:34:03 Downloading - Downloading input data
# 2020-12-27 15:34:03 Training - Training image download completed. Training in progress.
# 2020-12-27 15:34:03 Uploading - Uploading generated training model
# 2020-12-27 15:34:03 Completed - Training job completed

# %%
huggingface_estimator_loaded.model_data
# Out:
# 's3://sagemaker-eu-central-1-558105141721/huggingface-sdk-extension-2020-12-27-15-25-50-506/output/model.tar.gz'

# %% [markdown]
# ### Download model from s3

# %% [markdown]
# **using huggingface utils**

# %%
from huggingface.utils import download_model

download_model(model_data=huggingface_estimator_loaded.model_data,
               unzip=True,
               model_dir=huggingface_estimator_loaded.latest_training_job.name)

# %% [markdown]
# **using class built-in method**

# %%
huggingface_estimator.download_model(unzip=False)

# %% [markdown]
# ### Access logs
#
# until [PR](https://github.com/aws/sagemaker-python-sdk/pull/2059) is merged

# %%
huggingface_estimator.sagemaker_session.logs_for_job(huggingface_estimator.latest_training_job.name, wait=True)
# Out:
# 2020-12-27 15:34:03 Starting - Preparing the instances for training
# 2020-12-27 15:34:03 Downloading - Downloading input data
# 2020-12-27 15:34:03 Training - Training image download completed. Training in progress.
# 2020-12-27 15:34:03 Uploading - Uploading generated training model
# 2020-12-27 15:34:03 Completed - Training job completedbash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-12-27 15:32:15,198 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2020-12-27 15:32:15,221 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-12-27 15:32:18,249 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-12-27 15:32:18,802 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "train_batch_size": 32,
#         "model_name": "distilbert-base-uncased",
#         "epochs": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "huggingface-sdk-extension-2020-12-27-15-25-50-506",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-central-1-558105141721/huggingface-sdk-extension-2020-12-27-15-25-50-506/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":1,"model_name":"distilbert-base-uncased","train_batch_size":32}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-central-1-558105141721/huggingface-sdk-extension-2020-12-27-15-25-50-506/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1,"model_name":"distilbert-base-uncased","train_batch_size":32},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"huggingface-sdk-extension-2020-12-27-15-25-50-506","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-central-1-558105141721/huggingface-sdk-extension-2020-12-27-15-25-50-506/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--epochs","1","--model_name","distilbert-base-uncased","--train_batch_size","32"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_TRAIN_BATCH_SIZE=32
# SM_HP_MODEL_NAME=distilbert-base-uncased
# SM_HP_EPOCHS=1
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python train.py --epochs 1 --model_name distilbert-base-uncased --train_batch_size 32
#
#
# 2020-12-27 15:32:22,212 - __main__ - INFO -  loaded train_dataset length is: 2000
# 2020-12-27 15:32:22,213 - __main__ - INFO -  loaded test_dataset length is: 150
# 2020-12-27 15:32:22,511 - filelock - INFO - Lock 140208028323288 acquired on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2020-12-27 15:32:22,796 - filelock - INFO - Lock 140208028323288 released on /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361.lock
# 2020-12-27 15:32:23,079 - filelock - INFO - Lock 140208028162648 acquired on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# 2020-12-27 15:32:28,027 - filelock - INFO - Lock 140208028162648 released on /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a.lock
# [2020-12-27 15:32:33.312 algo-1:25 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-12-27 15:32:33.312 algo-1:25 INFO hook.py:193] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-12-27 15:32:33.312 algo-1:25 INFO hook.py:238] Saving to /opt/ml/output/tensors
# [2020-12-27 15:32:33.312 algo-1:25 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2020-12-27 15:32:33.329 algo-1:25 INFO hook.py:398] Monitoring the collections: losses
# [2020-12-27 15:32:33.329 algo-1:25 INFO hook.py:461] Hook is writing from the hook with pid: 25
#
# [2020-12-27 15:32:34.658 algo-1:25 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert.transformer BaseModelOutput
# [2020-12-27 15:32:34.659 algo-1:25 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:distilbert BaseModelOutput
# [2020-12-27 15:32:34.752 algo-1:25 WARNING hook.py:978] var is not Tensor or list or tuple of Tensors, module_name:DistilBertForSequenceClassification SequenceClassifierOutput
# {'eval_loss': 0.6371354460716248, 'eval_accuracy': 0.8533333333333334, 'eval_f1': 0.8253968253968254, 'eval_precision': 0.8666666666666667, 'eval_recall': 0.7878787878787878, 'epoch': 1.0}
# {'epoch': 1.0}
# ***** Eval results *****
# #015Downloading:   0%|          | 0.00/442 [00:00<?, ?B/s]#015Downloading: 100%|██████████| 442/442 [00:00<00:00, 429kB/s]
# #015Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]#015Downloading:   2%|▏         | 4.28M/268M [00:00<00:06, 42.8MB/s]#015Downloading:   3%|▎         | 9.31M/268M [00:00<00:05, 44.8MB/s]#015Downloading:   5%|▌         | 14.6M/268M [00:00<00:05, 47.1MB/s]#015Downloading:   7%|▋         | 20.0M/268M [00:00<00:05, 48.9MB/s]#015Downloading:  10%|▉         | 25.5M/268M [00:00<00:04, 50.6MB/s]#015Downloading:  12%|█▏        | 31.0M/268M [00:00<00:04, 51.8MB/s]#015Downloading:  14%|█▎        | 36.5M/268M [00:00<00:04, 52.8MB/s]#015Downloading:  16%|█▌        | 42.0M/268M [00:00<00:04, 53.3MB/s]#015Downloading:  18%|█▊        | 47.5M/268M [00:00<00:04, 53.9MB/s]#015Downloading:  20%|█▉        | 53.1M/268M [00:01<00:03, 54.5MB/s]#015Downloading:  22%|██▏       | 58.7M/268M [00:01<00:03, 54.9MB/s]#015Downloading:  24%|██▍       | 64.4M/268M [00:01<00:03, 55.4MB/s]#015Downloading:  26%|██▌       | 70.0M/268M [00:01<00:03, 55.7MB/s]#015Downloading:  28%|██▊       | 75.6M/268M [00:01<00:03, 55.8MB/s]#015Downloading:  30%|███       | 81.3M/268M [00:01<00:03, 56.1MB/s]#015Downloading:  32%|███▏      | 86.9M/268M [00:01<00:03, 56.0MB/s]#015Downloading:  35%|███▍      | 92.6M/268M [00:01<00:03, 56.2MB/s]#015Downloading:  37%|███▋      | 98.2M/268M [00:01<00:03, 55.6MB/s]#015Downloading:  39%|███▊      | 104M/268M [00:01<00:02, 55.5MB/s] #015Downlo
/s]#015 87%|████████▋ | 55/63 [00:29<00:04,  1.97it/s]#015 89%|████████▉ | 56/63 [00:29<00:03,  1.98it/s]#015 90%|█████████ | 57/63 [00:30<00:03,  1.98it/s]#015 92%|█████████▏| 58/63 [00:30<00:02,  1.98it/s]#015 94%|█████████▎| 59/63 [00:31<00:02,  1.98it/s]#015 95%|█████████▌| 60/63 [00:31<00:01,  1.99it/s]#015 97%|█████████▋| 61/63 [00:32<00:01,  1.98it/s]#015 98%|█████████▊| 62/63 [00:32<00:00,  1.98it/s]#015100%|██████████| 63/63 [00:33<00:00,  2.30it/s]
# #015  0%|          | 0/3 [00:00<?, ?it/s]#033[A
# #015 67%|██████▋   | 2/3 [00:00<00:00,  7.28it/s]#033[A
# #015100%|██████████| 3/3 [00:00<00:00,  5.59it/s]#033[A#015                                               #015
# #015                                             #015#033[A#015100%|██████████| 63/63 [00:33<00:00,  2.30it/s]
# #015100%|██████████| 3/3 [00:00<00:00,  5.59it/s]#033[A
# #015                                             #033[A#015                                               #015#015100%|██████████| 63/63 [00:33<00:00,  2.30it/s]#015100%|██████████| 63/63 [00:33<00:00,  1.86it/s]
# #015  0%|          | 0/3 [00:00<?, ?it/s]#015 67%|██████▋   | 2/3 [00:00<00:00,  7.23it/s]#015100%|██████████| 3/3 [00:00<00:00,  5.55it/s]#015100%|██████████| 3/3 [00:00<00:00,  4.65it/s]
# 2020-12-27 15:33:08,975 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# Training seconds: 316
# Billable seconds: 95
# Managed Spot Training savings: 69.9%

# %% [markdown]
# **after merged PR**

# %%
huggingface_estimator.logs()
# Out:
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# <ipython-input-85-c8bf5df398ca> in <module>
# ----> 1 huggingface_estimator.logs()
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/estimator.py in logs(self)
#     816         on which instance the log entry is from.
#     817         """
# --> 818         self.sagemaker_session.logs_for_job(self.latest_training_job, wait=True)
#     819
#     820     def deploy(
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3544         """
#    3545
# -> 3546         description = self.sagemaker_client.describe_training_job(TrainingJobName=job_name)
#    3547         print(secondary_training_status_message(description, None), end="")
#    3548
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     646             'auth_type': operation_model.auth_type,
#     647         }
# --> 648         request_dict = self._convert_to_request_dict(
#     649             api_params, operation_model, context=request_context)
#     650
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/botocore/client.py in _convert_to_request_dict(self, api_params, operation_model, context)
#     694         api_params = self._emit_api_params(
#     695             api_params, operation_model, context)
# --> 696         request_dict = self._serializer.serialize_to_request(
#     697             api_params, operation_model)
#     698         if not self._client_config.inject_host_prefix:
#
# ~/.anaconda3/envs/hf/lib/python3.8/site-packages/botocore/validate.py in serialize_to_request(self, parameters, operation_model)
#     295                                                     operation_model.input_shape)
#     296             if report.has_errors():
# --> 297                 raise ParamValidationError(report=report.generate_report())
#     298         return self._serializer.serialize_to_request(parameters,
#     299                                                      operation_model)
#
# ParamValidationError: Parameter validation failed:
# Invalid type for parameter TrainingJobName, value: <sagemaker.estimator._TrainingJob object at 0x7ffc4af0d520>, type: <class 'sagemaker.estimator._TrainingJob'>, valid types: <class 'str'>
